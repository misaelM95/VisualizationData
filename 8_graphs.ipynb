# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1,50,100)

# %% [markdown]
# HISTOGRAMA
# -DISTRIBUCIÓN Y FREQUENCIA-

# %%
plt.hist(data,bins=10,width=5,histtype='bar')
plt.show()

# %%
plt.hist(data,bins=10,histtype='step')
plt.show()

# %% [markdown]
# BOXPLOT -DISTRIBUCIÓN DE DATOS-

# %%
plt.boxplot(data,vert=False,patch_artist=True,notch=True)
plt.show()

# %%
data = np.append(data,200)
plt.boxplot(data,vert=False,patch_artist=True,notch=True,showfliers=False)
plt.show()

# %% [markdown]
# SCATTER -DISPERSIÓN- -SE UTILIZA PARA SABER SI TIENE CORRELACIÓN-

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N)) **2
colors = np.random.rand(N)

# %%
#market='p'->poligono
#market='x'->Nos arroja X's
#market='<'->Triangulos
#market='o'->Default
plt.scatter(x,y,s=area,c=colors,marker='*',alpha=0.5)
plt.show()
